# %%
from random import seed
from random import randrange
from datetime import datetime
from random import shuffle

#globals
kind = {"heart", "diamond", "spade", "club"}
number = {"ace", 2, 3, 4, 5, 6, 7, 8, 9, 10, "jack", "queen", "king"}
player_won = False
player_sum = 0


deck = [(k,n) for k in kind for n in number]
players_deck = set()
computers_deck = set()


#functions
def hand_value(given_set):
    card_sum = 0
    for card in given_set:
        card_sum += card
    return card_sum

def card_value(card):
    if card in ["jack", "queen", "king"]:
        return 10
    elif card == "ace":
        ace = int(input("You want the ace equal to 1 or 11? "))
        if ace == 1:
            return 1
        else:
            return 11
    else:
        return card

def player_plays():
    global player_lost
    global player_sum
    cards_in_hand = []
    answer = "y"
    
    while answer == "y":
        print(f"--- Round {len(cards_in_hand)+1} ---")
        print("Drawing one more card. ")
        card_drawn = deck.pop()
        cards_in_hand.append(card_drawn)
        print(f"Player currently has {len(cards_in_hand)} card in his hand.")
        print(f"The card that is drawn is: {card_drawn}")
        player_sum += card_value(card_drawn[1])
        print(f"Your cards total value is: {player_sum}")
        if player_sum > 21:
            print("Exceeded 21, you lose.")
            break
        elif player_sum == 21:
            print("You hit exactly 21, you won!")
            player_won = True
            break
        else:
            answer = input("Do you want to draw one more card? ")
            if answer == "n":
                break

    print("Player's final hand is: ",end=" -- ")
    for card in cards_in_hand:
        print (card, end = " -- ")
    print("\nPlayer's hand total value: - ||| "+str(player_sum)+" ||| -")

def computer_plays():
    computer_sum = 0
    cards_in_computer = []
    print("Player sum = "+str(player_sum))
    while computer_sum < player_sum and computer_sum < 21:
        print(f"--- Round {len(cards_in_computer)+1} ---")
        print("Drawing next card for computer.")
        card_drawn = deck.pop()
        print(f"The card it just drew was: {card_drawn}.")
        computer_sum += card_value(card_drawn[1])
        print(f"Computer's current sum is: {computer_sum}")
        cards_in_computer.append(card_drawn)

    print("Computer's final hand is: ",end=" -- ")
    for card in cards_in_computer:
        print (card, end = " -- ")
    print("\nComputer's total value: - ||| "+str(computer_sum)+" ||| -")
    who_won(computer_sum)

def who_won(comp_sum):
    winner = "Draw"
    if (comp_sum > player_sum and player_sum < 21):
        winner = "Computer"
    elif (comp_sum == player_sum and player_sum < 21):
        winner = "Draw"
    elif (comp_sum > 21 and player_sum > 21):
        winner = "Both Lost"
    print(f"++++ {winner} ++++")
    
    
#main
def main():
    seed(datetime.now().timestamp())
    shuffle(deck)
    print("===== GAME STARTS =====")
    print("===== PLAYER PLAYS =====")
    player_plays()
    print(" ===== PLAYER ENDED =====")
    if not player_won:
        computer_plays()
    print(" ===== COMPUTER ENDED =====")
    print("\n===== GAME ENDED =====")
main()
# Out:
# ===== GAME STARTS =====
# ===== PLAYER PLAYS =====
# --- Round 1 ---
# Drawing one more card.
# Player currently has 1 card in his hand.
# The card that is drawn is: ('heart', 'jack')
# Your cards total value is: 10
# Do you want to draw one more card?  y
# --- Round 2 ---
# Drawing one more card.
# Player currently has 2 card in his hand.
# The card that is drawn is: ('spade', 8)
# Your cards total value is: 18
# Do you want to draw one more card?  n
# Player's final hand is:  -- ('heart', 'jack') -- ('spade', 8) --
# Player's hand total value: - ||| 18 ||| -
#  ===== PLAYER ENDED =====
# Player sum = 18
# --- Round 1 ---
# Drawing next card for computer.
# The card it just drew was: ('club', 10).
# Computer's current sum is: 10
# --- Round 2 ---
# Drawing next card for computer.
# The card it just drew was: ('diamond', 'queen').
# Computer's current sum is: 20
# Computer's final hand is:  -- ('club', 10) -- ('diamond', 'queen') --
# Computer's total value: - ||| 20 ||| -
# ++++ Computer ++++
#  ===== COMPUTER ENDED =====
#
# ===== GAME ENDED =====
