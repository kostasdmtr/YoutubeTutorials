# %%
from random import seed
from random import randrange
from datetime import datetime
from random import shuffle

#globals
kind = {"heart", "diamond", "spade", "club"}
number = {"ace", 2, 3, 4, 5, 6, 7, 8, 9, 10, "jack", "queen", "king"}

deck = [(k,n) for k in kind for n in number]
players_deck = set()
computers_deck = set()


#functions
def hand_value(given_set):
    card_sum = 0
    for card in given_set:
        card_sum += card
    return card_sum

def card_value(card):
    if card in ["jack", "queen", "king"]:
        return 10
    elif card == "ace":
        ace = int(input("You want the ace equal to 1 or 11? "))
        if ace == 1:
            return 1
        else:
            return 11
    else:
        return card

def player_plays():
    player_sum = 0
    print("Drawing first card.")
    card_tuple = deck.pop()
    print(f"The card that is drawn is: {card_tuple} and its value is: {card_value(card_tuple[1])}")
    


#main
def main():
    seed(datetime.now().timestamp())
    shuffle(deck)
    
    player_plays()
         
main()
# Out:
# Drawing first card.
# You want the ace equal to 1 or 11?  1
# The card that is drawn is: ('diamond', 'ace') and its value is: 1
