# %% [markdown]
# # Python tutorials

# %%
numbers = (1,2,3,4,3,2,3,3)

# %%
print("Length is: "+str(len(numbers)))
print("Min is: "+str(min(numbers)))
print("Number of 3s are: "+str(numbers.count(3)))
print("Index of the first 3 is: "+str(numbers.index(3)))
# Out:
# Length is: 8
# Min is: 1
# Number of 3s are: 4
# Index of the first 3 is: 2
